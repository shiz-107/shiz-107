# %% [markdown]
# <a href="https://colab.research.google.com/github/shiz-107/shiz-107/blob/main/Long_Codes_to_find_out_the_Parameters_of_Isogenous_Super_Singular_Montgomery_Elliptic_curves_Over_the_Finite_field_of_Gaussian_Integers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# points on curve :-
j = complex(0, 1)
p = 107
a = 6j+6
count=0
R=[]
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
print(count)

# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
target_order = 2
points_with_order = find_points_with_order(target_order)
print("points_with_order_2:" , points_with_order)
final = []
for P in points_with_order:
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
print("next curves:" , final)
for element in final:
  a = element
  count=0
  R=[]
  for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
  print(count)

# Define a function to add two points on the curve
  def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
  def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

  def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
  target_order = 2
  points_with_order = find_points_with_order(target_order)
  print(f"points_with_order_2: {points_with_order} , element={element}")
  final = []
  for P in points_with_order:
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
  print("next curves:" , final)
  for element in final:
   a = element
   count=0
   R=[]
   for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
   print(count)

# Define a function to add two points on the curve
   def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
   def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

   def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
   target_order = 2
   points_with_order = find_points_with_order(target_order)
   print(f"points_with_order_2: {points_with_order} , element={element}")
   final = []
   for P in points_with_order:
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
        break
   else:
      continue
   break
   print("next curves:" , final)
# Out:
# 11663
# points_with_order_2: [(0j, 0j), ((39+66j), 0j), ((62+35j), 0j)]
# next curves: [(2+0j), 59j, (12+81j)]
# 11448
# points_with_order_2: [(0j, 0j), ((106+0j), 0j)] , element=(2+0j)
# next curves: [(2+0j), (105+0j)]
# 11448
# points_with_order_2: [(0j, 0j), ((106+0j), 0j)] , element=(2+0j)
# 11663
# points_with_order_2: [(0j, 0j), (8j, 0j), (40j, 0j)] , element=59j
# next curves: [(2+0j), (44+0j), (89+0j)]
# 11448
# points_with_order_2: [(0j, 0j), ((106+0j), 0j)] , element=(2+0j)
# 11663
# points_with_order_2: [(0j, 0j), ((15+101j), 0j), ((80+32j), 0j)] , element=(12+81j)
# next curves: [(2+0j), (102+78j), (5+64j)]
# 11448
# points_with_order_2: [(0j, 0j), ((106+0j), 0j)] , element=(2+0j)

# %%
j = complex(0, 1)
p = 107
a = 6j + 6
count = 0
R = []
for m in range(p):
    for n in range(p):
        i = m + n * j

        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i, k))
                    count += 1
print(count)


# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
target_order = 2
points_with_order = find_points_with_order(target_order)
print("points_with_order_2:" , points_with_order)
final = []
for P in points_with_order:
        if P[0] == 0:
            continue
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
print("next curves:" , final)
for i in range(3):
 for element in final:
  a = element
  count=0
  R=[]
  for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
  print(count)

# Define a function to add two points on the curve
  def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
  def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

  def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
  target_order = 2
  points_with_order = find_points_with_order(target_order)
  print(f"points_with_order_2: {points_with_order} , element={element}")
  final = []
  for P in points_with_order:
        if P[0]==0:
          continue
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
  print("next curves:" , final)
  for i in range (3):
   for element in final:
    a = element
    count=0
    R=[]
    for m in range(p):
     for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
    print(count)

# Define a function to add two points on the curve
    def point_addition(P, Q):
     if P is None:
        return Q
     if Q is None:
        return P

     if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

     if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

     Rx = slope**2 - a - P[0] - Q[0]
     Rx_prime = complex(Rx.real % p, Rx.imag % p)
     Ry = -(P[1] + slope * (Rx_prime - P[0]))
     Ry_prime = complex(Ry.real % p, Ry.imag % p)
     return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
    def point_order(P):
     if P is None:
        return 1
     Q = P
     order = 1
     while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
     return order

    def find_points_with_order(order):
     points = []
     for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
     return points
    target_order = 2
    points_with_order = find_points_with_order(target_order)
    print(f"points_with_order_2: {points_with_order} , element={element}")
    final = []
    for P in points_with_order:
        if P[0]==0:
          continue
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
    print("next curves:" , final)
# Out:
# 11663
# points_with_order_2: [(0j, 0j), ((39+66j), 0j), ((62+35j), 0j)]
# next curves: [59j, (12+81j)]
# 11663
# points_with_order_2: [(0j, 0j), (8j, 0j), (40j, 0j)] , element=59j
# next curves: [(44+0j), (89+0j)]
# 11663
# points_with_order_2: [(0j, 0j), ((85+42j), 0j), ((85+65j), 0j)] , element=(44+0j)
# next curves: [(93+9j), (93+98j)]
# 11663
# points_with_order_2: [(0j, 0j), ((9+53j), 0j), ((9+54j), 0j)] , element=(89+0j)
# next curves: [36j, 71j]
# 11663
# points_with_order_2: [(0j, 0j), (87j, 0j), (91j, 0j)] , element=36j
# next curves: [(104+0j), (63+0j)]
# 11663
# points_with_order_2: [(0j, 0j), (16j, 0j), (20j, 0j)] , element=71j
# next curves: [(63+0j), (104+0j)]
# 11663
# points_with_order_2: [(0j, 0j), ((22+42j), 0j), ((22+65j), 0j)] , element=(63+0j)
# next curves: [(93+98j), (93+9j)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3c299ac962c0> in <cell line: 149>()
#     312                 imaginary_part = z.imag % p
#     313                 Y = real_part + imaginary_part * 1j
# --> 314                 if X == Y:
#     315                     R.append((i,k))
#     316                     count+=1
#
# KeyboardInterrupt:

# %%
j = complex(0, 1)
p = 107
a = 6j + 6
count = 0
R = []
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i, k))
                    count += 1
print(count)

# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points

target_order = 2
points_with_order = find_points_with_order(target_order)
print("points_with_order_2:", points_with_order)
final = []
seen_points = set()
# FIRST LOOP
for P in points_with_order:
    if P[0] == 0:
        continue
    if P in seen_points:
        continue
    a_prime = 2 * (1 - 2 * P[0] ** 2)
    result = complex(a_prime.real % p, a_prime.imag % p)
    final.append(result)
print("next curves:", final)
# SECOND LOOP
for i in range(2):
 for element in final:
  a = element
  count=0
  R=[]
  for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
  print(count)

# Define a function to add two points on the curve
  def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope**2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
  def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

  def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
  target_order = 2
  points_with_order = find_points_with_order(target_order)
  print(f"points_with_order_2: {points_with_order} , element={element}")
  final = []
  seen_points = set()
  for P in points_with_order:
        if P[0]==0:
          continue
        if P in seen_points:
          continue
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
  print("next curves:" , final)
# 3RD LOOP
  for i in range (2):
   for element in final:
    a = element
    count=0
    R=[]
    for m in range(p):
     for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
    print(count)

# Define a function to add two points on the curve
    def point_addition(P, Q):
     if P is None:
        return Q
     if Q is None:
        return P

     if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

     if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

     Rx = slope**2 - a - P[0] - Q[0]
     Rx_prime = complex(Rx.real % p, Rx.imag % p)
     Ry = -(P[1] + slope * (Rx_prime - P[0]))
     Ry_prime = complex(Ry.real % p, Ry.imag % p)
     return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
    def point_order(P):
     if P is None:
        return 1
     Q = P
     order = 1
     while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
     return order

    def find_points_with_order(order):
     points = []
     for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
     return points
    target_order = 2
    points_with_order = find_points_with_order(target_order)
    print(f"points_with_order_2: {points_with_order} , element={element}")
    final = []
    seen_points = set()
    for P in points_with_order:
        if P[0]==0:
          continue
        if P in seen_points:
          continue
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
    print("next curves:" , final)
# 4TH LOOP
    for i in range (2):
     for element in final:
      a = element
      count=0
      R=[]
      for m in range(p):
       for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i * 1)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j
                if X == Y:
                    R.append((i,k))
                    count+=1
      print(count)

# Define a function to add two points on the curve
      def point_addition(P, Q):
       if P is None:
         return Q
       if Q is None:
         return P

       if P == Q:
         num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
         num_prime = complex(num.real % p, num.imag % p)
         den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
         conj_den = den.real % p + (p - den.imag) % p * j
         ab = ((den.real) ** 2 + (den.imag) ** 2) % p

         def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
         element = ab
         mod = p
         inverse = find_inverse(element, mod)

         if inverse is None:
            return None

         den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
         slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

       if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

       Rx = slope**2 - a - P[0] - Q[0]
       Rx_prime = complex(Rx.real % p, Rx.imag % p)
       Ry = -(P[1] + slope * (Rx_prime - P[0]))
       Ry_prime = complex(Ry.real % p, Ry.imag % p)
       return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
      def point_order(P):
       if P is None:
        return 1
       Q = P
       order = 1
       while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
       return order

      def find_points_with_order(order):
       points = []
       for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
       return points
      target_order = 2
      points_with_order = find_points_with_order(target_order)
      print(f"points_with_order_2: {points_with_order} , element={element}")
      final = []
      seen_points = set()
      for P in points_with_order:
        if P[0]==0:
          continue
        if P in seen_points:
          continue
        a_prime = 2*(1-2*P[0]**2)
        result = complex(a_prime.real%p , a_prime.imag%p)
        final.append(result)
      print("next curves:" , final)
# Out:
# 11663
# points_with_order_2: [(0j, 0j), ((39+66j), 0j), ((62+35j), 0j)]
# next curves: [59j, (12+81j)]
# 11663
# points_with_order_2: [(0j, 0j), (8j, 0j), (40j, 0j)] , element=59j
# next curves: [(44+0j), (89+0j)]
# 11663
# points_with_order_2: [(0j, 0j), ((85+42j), 0j), ((85+65j), 0j)] , element=(44+0j)
# next curves: [(93+9j), (93+98j)]
# 11663
# points_with_order_2: [(0j, 0j), ((17+94j), 0j), ((104+4j), 0j)] , element=(93+9j)
# next curves: [(57+56j), (30+96j)]
# 11663
# points_with_order_2: [(0j, 0j), ((17+13j), 0j), ((104+103j), 0j)] , element=(93+98j)
# next curves: [(57+51j), (30+11j)]
# 11663
# points_with_order_2: [(0j, 0j), ((16+81j), 0j), ((34+82j), 0j)] , element=(57+51j)
# next curves: [(77+11j), (18+59j)]
# 11663
# points_with_order_2: [(0j, 0j), ((22+43j), 0j), ((55+53j), 0j)] , element=(30+11j)
# next curves: [(5+29j), (101+6j)]
# 11663
# points_with_order_2: [(0j, 0j), ((9+53j), 0j), ((9+54j), 0j)] , element=(89+0j)
# next curves: [36j, 71j]
# 11663
# points_with_order_2: [(0j, 0j), (87j, 0j), (91j, 0j)] , element=36j
# next curves: [(104+0j), (63+0j)]
# 11663
# points_with_order_2: [(0j, 0j), (16j, 0j), (20j, 0j)] , element=71j
# next curves: [(63+0j), (104+0j)]
# 11663
# points_with_order_2: [(0j, 0j), ((22+42j), 0j), ((22+65j), 0j)] , element=(63+0j)
# next curves: [(93+98j), (93+9j)]
# 11663
# points_with_order_2: [(0j, 0j), ((55+20j), 0j), ((55+87j), 0j)] , element=(104+0j)
# next curves: [(95+81j), (95+26j)]
# 11663
# points_with_order_2: [(0j, 0j), ((27+32j), 0j), ((92+101j), 0j)] , element=(95+81j)
# next curves: [(5+43j), (102+29j)]
# 11663
# points_with_order_2: [(0j, 0j), ((3+105j), 0j), ((99+66j), 0j)] , element=(5+43j)
# next curves: [(89+48j), (50+51j)]
# 11663
# points_with_order_2: [(0j, 0j), ((12+38j), 0j), ((100+40j), 0j)] , element=(102+29j)
# next curves: [(66+97j), 100j]
# 11663
# points_with_order_2: [(0j, 0j), ((70+73j), 0j), ((78+44j), 0j)] , element=(66+97j)
# next curves: [(6+101j), (102+43j)]
# 11663
# points_with_order_2: [(0j, 0j), (38j, 0j), (76j, 0j)] , element=100j
# next curves: [0j, (101+0j)]
# 11663
# points_with_order_2: [(0j, 0j), ((27+75j), 0j), ((92+6j), 0j)] , element=(95+26j)
# next curves: [(5+64j), (102+78j)]
# 11663
# points_with_order_2: [(0j, 0j), ((3+2j), 0j), ((99+41j), 0j)] , element=(5+64j)
# next curves: [(89+59j), (50+56j)]
# 11663
# points_with_order_2: [(0j, 0j), ((12+69j), 0j), ((100+67j), 0j)] , element=(102+78j)
# next curves: [(66+10j), 7j]
# 11663
# points_with_order_2: [(0j, 0j), ((70+34j), 0j), ((78+63j), 0j)] , element=(66+10j)
# next curves: [(6+6j), (102+64j)]
# 11663
# points_with_order_2: [(0j, 0j), (31j, 0j), (69j, 0j)] , element=7j
# next curves: [(101+0j), 0j]
# 11663
# points_with_order_2: [(0j, 0j), ((15+101j), 0j), ((80+32j), 0j)] , element=(12+81j)
# next curves: [(102+78j), (5+64j)]
# 11663
# points_with_order_2: [(0j, 0j), ((12+69j), 0j), ((100+67j), 0j)] , element=(102+78j)
# next curves: [(66+10j), 7j]
# 11663
# points_with_order_2: [(0j, 0j), ((70+34j), 0j), ((78+63j), 0j)] , element=(66+10j)
# next curves: [(6+6j), (102+64j)]
# 11663
# points_with_order_2: [(0j, 0j), (31j, 0j), (69j, 0j)] , element=7j
# next curves: [(101+0j), 0j]
# 11663
# points_with_order_2: [(0j, 0j), ((3+45j), 0j), ((3+62j), 0j)] , element=(101+0j)
# next curves: [(41+97j), (41+10j)]
# 11663
# points_with_order_2: [(0j, 0j), (1j, 0j), (106j, 0j)] , element=0j
# next curves: [(6+0j), (6+0j)]
# 11663
# points_with_order_2: [(0j, 0j), ((3+2j), 0j), ((99+41j), 0j)] , element=(5+64j)
# next curves: [(89+59j), (50+56j)]
# 11663
# points_with_order_2: [(0j, 0j), ((44+21j), 0j), ((81+27j), 0j)] , element=(89+59j)
# next curves: [(14+98j), 52j]
# 11663
# points_with_order_2: [(0j, 0j), ((73+25j), 0j), ((91+26j), 0j)] , element=(50+56j)
# next curves: [(18+59j), (77+11j)]
# 11663
# points_with_order_2: [(0j, 0j), ((26+27j), 0j), ((63+21j), 0j)] , element=(18+59j)
# next curves: [55j, (14+9j)]
# 11663
# points_with_order_2: [(0j, 0j), ((52+53j), 0j), ((85+43j), 0j)] , element=(77+11j)
# next curves: [(101+101j), (5+78j)]
